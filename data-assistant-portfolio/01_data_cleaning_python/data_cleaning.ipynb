# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data.csv")
df
# Out:
#     name           email   age   join_date
# 0  Ahmad  ahmad@mail.com  25.0  2023-01-10
# 1   Budi   budi@mail.com   NaN  2023-02-15
# 2  Citra  citra@mail.com  30.0         NaN
# 3   Dewi             NaN  28.0  2023-03-01

# %%
df.isnull().sum()
# Out:
# name         0
# email        1
# age          1
# join_date    1
# dtype: int64

# %%
df_clean = df.dropna()
df_clean
# Out:
#     name           email   age   join_date
# 0  Ahmad  ahmad@mail.com  25.0  2023-01-10

# %%
df_clean.to_csv("clean_data.csv", index=False)

# %%
print("Jumlah data sebelum cleaning:", len(df))
print("Jumlah data setelah cleaning:", len(df_clean))
# Out:
# Jumlah data sebelum cleaning: 4
# Jumlah data setelah cleaning: 1

# %%
df_clean.describe(include="all")
# Out:
#          name           email   age   join_date
# count       1               1   1.0           1
# unique      1               1   NaN           1
# top     Ahmad  ahmad@mail.com   NaN  2023-01-10
# freq        1               1   NaN           1
# mean      NaN             NaN  25.0         NaN
# std       NaN             NaN   NaN         NaN
# min       NaN             NaN  25.0         NaN
# 25%       NaN             NaN  25.0         NaN
# 50%       NaN             NaN  25.0         NaN
# 75%       NaN             NaN  25.0         NaN
# max       NaN             NaN  25.0         NaN
